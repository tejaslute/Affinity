# %%
import pandas as pd
df = pd.read_csv("Cleaned_Data_Col_6.csv")
df.head()
# Out:
#                      Placed In  Class 10 Percentage  Class 12 Percentage  \
# 0                    Teachnook                   59                   53
# 1                   eInfochips                   86                   73
# 2                     Rockwell                   83                   73
# 3  Cognizant (Genc), Capgemini                   93                   84
# 4                          NaN                   82                   73
#
#    Degree Percentage  Degree CGPA Number of Live Backlogs  \
# 0                 70            8                      na
# 1                 67            7                     NaN
# 2                 77            8                       0
# 3                 85            9                       0
# 4                 78            9                      na
#
#   Educational GAP (in Years) Year Down in Engineering (in Years)  \
# 0                        NaN                                   1
# ...

# %%
df.rename(columns = {"Number of Live Backlogs": "Live Backlogs"}, inplace=True)
df.head()
# Out:
#                      Placed In  Class 10 Percentage  Class 12 Percentage  \
# 0                    Teachnook                   59                   53
# 1                   eInfochips                   86                   73
# 2                     Rockwell                   83                   73
# 3  Cognizant (Genc), Capgemini                   93                   84
# 4                          NaN                   82                   73
#
#    Degree Percentage  Degree CGPA Live Backlogs Educational GAP (in Years)  \
# 0                 70            8            na                        NaN
# 1                 67            7           NaN                        NaN
# 2                 77            8             0                        NaN
# 3                 85            9             0                          1
# 4                 78            9            na                        NaN
#
#   Year Down in Engineering (in Years)  \
# ...

# %%
df['Live Backlogs'].unique()
# Out:
# array(['na', nan, '0', '00', 'No', 'Zero', 'zero', 'NONE', '-', 'NO',
#        '0 ZERO', '1 ( Practical)', 'NO live backlogs', 'Na', '5', '0.0',
#        '2', '1 practical', 'Zero (0)', 'None', '0 Backlog', '--', '1',
#        '8'], dtype=object)

# %%
def remove():
    df['Degree CGPA'].replace(['na','00', 'No', 'Zero', 'zero', 'NONE', '-', 'NO',
                                     '0 ZERO','NO live backlogs', 'Na','0.0', 'Zero (0)', 
                                     '0 Backlog', '--'], "0", inplace=True)
    df['Degree CGPA'].replace(['1 ( Practical)', '1 practical'], "1", inplace=True)
        
remove()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 856 entries, 0 to 855
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Placed In                            659 non-null    object
#  1   Class 10 Percentage                  856 non-null    int64
#  2   Class 12 Percentage                  856 non-null    int64
#  3   Degree Percentage                    856 non-null    int64
#  4   Degree CGPA                          856 non-null    int64
#  5   Live Backlogs                        843 non-null    object
#  6   Educational GAP (in Years)           624 non-null    object
#  7   Year Down in Engineering (in Years)  642 non-null    object
#  8   Internship Details                   291 non-null    object
#  9   BE Project Details                   165 non-null    object
# dtypes: int64(4), object(6)
# memory usage: 67.0+ KB

# %%
df.isnull().sum()
# Out:
# Placed In                              197
# Class 10 Percentage                      0
# Class 12 Percentage                      0
# Degree Percentage                        0
# Degree CGPA                              0
# Live Backlogs                           13
# Educational GAP (in Years)             232
# Year Down in Engineering (in Years)    214
# Internship Details                     565
# BE Project Details                     691
# dtype: int64

# %%
df['Live Backlogs'].unique()
# Out:
# array(['na', nan, '0', '00', 'No', 'Zero', 'zero', 'NONE', '-', 'NO',
#        '0 ZERO', '1 ( Practical)', 'NO live backlogs', 'Na', '5', '0.0',
#        '2', '1 practical', 'Zero (0)', 'None', '0 Backlog', '--', '1',
#        '8'], dtype=object)

# %% [markdown]
# # New started

# %%
df1 = pd.read_csv("Cleaned_data_Col_6.csv")
df1.head()
# Out:
#                      Placed In  Class 10 Percentage  Class 12 Percentage  \
# 0                    Teachnook                   59                   53
# 1                   eInfochips                   86                   73
# 2                     Rockwell                   83                   73
# 3  Cognizant (Genc), Capgemini                   93                   84
# 4                          NaN                   82                   73
#
#    Degree Percentage  Degree CGPA Number of Live Backlogs  \
# 0                 70            8                      na
# 1                 67            7                     NaN
# 2                 77            8                       0
# 3                 85            9                       0
# 4                 78            9                      na
#
#   Educational GAP (in Years) Year Down in Engineering (in Years)  \
# 0                        NaN                                   1
# ...

# %%
df1.rename(columns = {"Number of Live Backlogs": "Live Backlogs"}, inplace=True)
df1.head()
# Out:
#                      Placed In  Class 10 Percentage  Class 12 Percentage  \
# 0                    Teachnook                   59                   53
# 1                   eInfochips                   86                   73
# 2                     Rockwell                   83                   73
# 3  Cognizant (Genc), Capgemini                   93                   84
# 4                          NaN                   82                   73
#
#    Degree Percentage  Degree CGPA Live Backlogs Educational GAP (in Years)  \
# 0                 70            8            na                        NaN
# 1                 67            7           NaN                        NaN
# 2                 77            8             0                        NaN
# 3                 85            9             0                          1
# 4                 78            9            na                        NaN
#
#   Year Down in Engineering (in Years)  \
# ...

# %%
def remove():
    df1['Live Backlogs'].replace(['na','00', 'No', 'Zero', 'zero', 'NONE', '-', 'NO',
                                     '0 ZERO','NO live backlogs', 'Na','0.0', 'Zero (0)', 
                                     '0 Backlog', '--'], "0", inplace=True)
    df1['Live Backlogs'].replace(['1 ( Practical)', '1 practical'], "1", inplace=True)
remove()

# %%
df1['Live Backlogs'].unique()
# Out:
# array(['0', nan, '1', '5', '2', 'None', '8'], dtype=object)

# %%
df1['Live Backlogs'].value_counts()
# Out:
# 0       835
# 1         4
# 5         1
# 2         1
# None      1
# 8         1
# Name: Live Backlogs, dtype: int64

# %%
df1['Live Backlogs'] = df1['Live Backlogs'].fillna("0")
df1.isnull().sum()
# Out:
# Placed In                              197
# Class 10 Percentage                      0
# Class 12 Percentage                      0
# Degree Percentage                        0
# Degree CGPA                              0
# Live Backlogs                            0
# Educational GAP (in Years)             232
# Year Down in Engineering (in Years)    214
# Internship Details                     565
# BE Project Details                     691
# dtype: int64

# %%
df1['Live Backlogs'] = df1['Live Backlogs'].astype(float)
df1.info()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 df1['Live Backlogs'] = df1['Live Backlogs'].astype(float)
#       2 df1.info()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# ...

# %%
df1['Live Backlogs'].unique()
# Out:
# array(['0', '1', '5', '2', 'None', '8'], dtype=object)

# %%
df1.isnull().sum()
# Out:
# Placed In                              197
# Class 10 Percentage                      0
# Class 12 Percentage                      0
# Degree Percentage                        0
# Degree CGPA                              0
# Live Backlogs                            0
# Educational GAP (in Years)             232
# Year Down in Engineering (in Years)    214
# Internship Details                     565
# BE Project Details                     691
# dtype: int64

# %%
 df1['Live Backlogs'].replace('None', "0", inplace=True)

# %%
df1['Live Backlogs'].unique()
# Out:
# array(['0', '1', '5', '2', '8'], dtype=object)

# %%
df1['Live Backlogs'] = df1['Live Backlogs'].astype(float)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 856 entries, 0 to 855
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Placed In                            659 non-null    object
#  1   Class 10 Percentage                  856 non-null    int64
#  2   Class 12 Percentage                  856 non-null    int64
#  3   Degree Percentage                    856 non-null    int64
#  4   Degree CGPA                          856 non-null    int64
#  5   Live Backlogs                        856 non-null    float64
#  6   Educational GAP (in Years)           624 non-null    object
#  7   Year Down in Engineering (in Years)  642 non-null    object
#  8   Internship Details                   291 non-null    object
#  9   BE Project Details                   165 non-null    object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 67.0+ KB

# %%
df1.describe()
# Out:
#        Class 10 Percentage  Class 12 Percentage  Degree Percentage  \
# count           856.000000           856.000000         856.000000
# mean             85.507009            72.838785          78.461449
# std               7.577433             8.106582           7.858301
# min              57.000000            50.000000          43.000000
# 25%              82.000000            68.000000          74.000000
# 50%              87.000000            73.000000          78.000000
# 75%              92.000000            78.000000          84.000000
# max              98.000000            95.000000          99.000000
#
#        Degree CGPA  Live Backlogs
# count   856.000000     856.000000
# mean      8.661215       0.022196
# std       0.800404       0.336091
# min       5.000000       0.000000
# 25%       8.000000       0.000000
# 50%       9.000000       0.000000
# 75%       9.000000       0.000000
# max      10.000000       8.000000

# %%
df1['Live Backlogs'] =df1['Live Backlogs'].round(0)
df1.head()
# Out:
#                      Placed In  Class 10 Percentage  Class 12 Percentage  \
# 0                    Teachnook                   59                   53
# 1                   eInfochips                   86                   73
# 2                     Rockwell                   83                   73
# 3  Cognizant (Genc), Capgemini                   93                   84
# 4                          NaN                   82                   73
#
#    Degree Percentage  Degree CGPA  Live Backlogs Educational GAP (in Years)  \
# 0                 70            8            0.0                        NaN
# 1                 67            7            0.0                        NaN
# 2                 77            8            0.0                        NaN
# 3                 85            9            0.0                          1
# 4                 78            9            0.0                        NaN
#
#   Year Down in Engineering (in Years)  \
# ...

# %%
df1['Live Backlogs'] =df1['Live Backlogs'].astype(int)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 856 entries, 0 to 855
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Placed In                            659 non-null    object
#  1   Class 10 Percentage                  856 non-null    int64
#  2   Class 12 Percentage                  856 non-null    int64
#  3   Degree Percentage                    856 non-null    int64
#  4   Degree CGPA                          856 non-null    int64
#  5   Live Backlogs                        856 non-null    int32
#  6   Educational GAP (in Years)           624 non-null    object
#  7   Year Down in Engineering (in Years)  642 non-null    object
#  8   Internship Details                   291 non-null    object
#  9   BE Project Details                   165 non-null    object
# dtypes: int32(1), int64(4), object(5)
# memory usage: 63.7+ KB

# %%
df1['Live Backlogs'].value_counts()
# Out:
# 0    849
# 1      4
# 5      1
# 2      1
# 8      1
# Name: Live Backlogs, dtype: int64

# %% [markdown]
# # Live Backlogs Done

# %%
df1.head()
# Out:
#                      Placed In  Class 10 Percentage  Class 12 Percentage  \
# 0                    Teachnook                   59                   53
# 1                   eInfochips                   86                   73
# 2                     Rockwell                   83                   73
# 3  Cognizant (Genc), Capgemini                   93                   84
# 4                          NaN                   82                   73
#
#    Degree Percentage  Degree CGPA  Live Backlogs Educational GAP (in Years)  \
# 0                 70            8              0                        NaN
# 1                 67            7              0                        NaN
# 2                 77            8              0                        NaN
# 3                 85            9              0                          1
# 4                 78            9              0                        NaN
#
#   Year Down in Engineering (in Years)  \
# ...

# %%
df2 = df1
df2.head()
# Out:
#                      Placed In  Class 10 Percentage  Class 12 Percentage  \
# 0                    Teachnook                   59                   53
# 1                   eInfochips                   86                   73
# 2                     Rockwell                   83                   73
# 3  Cognizant (Genc), Capgemini                   93                   84
# 4                          NaN                   82                   73
#
#    Degree Percentage  Degree CGPA  Live Backlogs Educational GAP (in Years)  \
# 0                 70            8              0                        NaN
# 1                 67            7              0                        NaN
# 2                 77            8              0                        NaN
# 3                 85            9              0                          1
# 4                 78            9              0                        NaN
#
#   Year Down in Engineering (in Years)  \
# ...

# %%
df1.rename(columns = {"Educational GAP (in Years)": "Education Gap"}, inplace=True)
df1.head()
# Out:
#                      Placed In  Class 10 Percentage  Class 12 Percentage  \
# 0                    Teachnook                   59                   53
# 1                   eInfochips                   86                   73
# 2                     Rockwell                   83                   73
# 3  Cognizant (Genc), Capgemini                   93                   84
# 4                          NaN                   82                   73
#
#    Degree Percentage  Degree CGPA  Live Backlogs Education Gap  \
# 0                 70            8              0           NaN
# 1                 67            7              0           NaN
# 2                 77            8              0           NaN
# 3                 85            9              0             1
# 4                 78            9              0           NaN
#
#   Year Down in Engineering (in Years)  \
# 0                                   1
# 1                                 NaN
# ...

# %%
df1["Education Gap"].unique()
# Out:
# array([nan, '1', '0', 'No', 'None', '2', '00', 'Zero', '1 Years',
#        '0 year', 'NO', '3', '2017-2018', '0 Years', '-', 'no', '0.5 yrs',
#        '0.0', '1 YEAR', 'Nothing', '1 Year', '1 year', '01', '2.5',
#        '1 Year (2017)', 'NIL', 'No gap', '2019', '--', 'ONE YEAR',
#        '2 YEAR AFTER DIPLOMA', '1Y'], dtype=object)

# %%
df1.to_csv(r"C:\Users\Rohit Bhapkar\Desktop\Be Project\Final Model\Cleaned_data_Col_7.csv", index=False)

# %%
def remove():
    df1['Education Gap'].replace(['No', 'None','00', 'Zero', '0 year', 'NO','0 Years', '-', 'no',
                                  '0.0', 'Nothing', 'NIL', 'No gap', '--' ], "0", inplace=True)
    
    df1['Education Gap'].replace(['1 Years', '0.5 yrs','1 YEAR', '1 Year', '1 year','01', '1 Year (2017)', 
                                  '2019','ONE YEAR',  '1Y' , '2017-2018'], "1", inplace=True)
    
    df1['Education Gap'].replace(['3', '2.5','2 YEAR AFTER DIPLOMA' ], "2", inplace=True)
remove()

# %%
df1['Education Gap'].unique()
# Out:
# array([nan, '1', '0', '2'], dtype=object)

# %%
df1.isnull().sum()
# Out:
# Placed In                              197
# Class 10 Percentage                      0
# Class 12 Percentage                      0
# Degree Percentage                        0
# Degree CGPA                              0
# Live Backlogs                            0
# Education Gap                          232
# Year Down in Engineering (in Years)    214
# Internship Details                     565
# BE Project Details                     691
# dtype: int64

# %%
df1['Education Gap'] = df1['Education Gap'].astype(float)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 856 entries, 0 to 855
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Placed In                            659 non-null    object
#  1   Class 10 Percentage                  856 non-null    int64
#  2   Class 12 Percentage                  856 non-null    int64
#  3   Degree Percentage                    856 non-null    int64
#  4   Degree CGPA                          856 non-null    int64
#  5   Live Backlogs                        856 non-null    int32
#  6   Education Gap                        624 non-null    float64
#  7   Year Down in Engineering (in Years)  642 non-null    object
#  8   Internship Details                   291 non-null    object
#  9   BE Project Details                   165 non-null    object
# dtypes: float64(1), int32(1), int64(4), object(4)
# memory usage: 63.7+ KB

# %%
df1.describe()
# Out:
#        Class 10 Percentage  Class 12 Percentage  Degree Percentage  \
# count           856.000000           856.000000         856.000000
# mean             85.507009            72.838785          78.461449
# std               7.577433             8.106582           7.858301
# min              57.000000            50.000000          43.000000
# 25%              82.000000            68.000000          74.000000
# 50%              87.000000            73.000000          78.000000
# 75%              92.000000            78.000000          84.000000
# max              98.000000            95.000000          99.000000
#
#        Degree CGPA  Live Backlogs  Education Gap
# count   856.000000     856.000000     624.000000
# mean      8.661215       0.022196       0.115385
# std       0.800404       0.336091       0.366521
# min       5.000000       0.000000       0.000000
# 25%       8.000000       0.000000       0.000000
# 50%       9.000000       0.000000       0.000000
# ...

# %%
df1['Education Gap'] = df1['Education Gap'].fillna("0")
df1.isnull().sum()
# Out:
# Placed In                              197
# Class 10 Percentage                      0
# Class 12 Percentage                      0
# Degree Percentage                        0
# Degree CGPA                              0
# Live Backlogs                            0
# Education Gap                            0
# Year Down in Engineering (in Years)    214
# Internship Details                     565
# BE Project Details                     691
# dtype: int64

# %%
df1['Education Gap'].unique()
# Out:
# array(['0', 1.0, 0.0, 2.0], dtype=object)

# %%
df1['Education Gap'] = df1['Education Gap'].astype(int)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 856 entries, 0 to 855
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Placed In                            659 non-null    object
#  1   Class 10 Percentage                  856 non-null    int64
#  2   Class 12 Percentage                  856 non-null    int64
#  3   Degree Percentage                    856 non-null    int64
#  4   Degree CGPA                          856 non-null    int64
#  5   Live Backlogs                        856 non-null    int32
#  6   Education Gap                        856 non-null    int32
#  7   Year Down in Engineering (in Years)  642 non-null    object
#  8   Internship Details                   291 non-null    object
#  9   BE Project Details                   165 non-null    object
# dtypes: int32(2), int64(4), object(4)
# memory usage: 60.3+ KB

# %%
df1.to_csv(r"C:\Users\Rohit Bhapkar\Desktop\Be Project\Final Model\Cleaned_data_Col_8.csv", index=False)

# %% [markdown]
# # Education Gap done

# %%
df1.head()
# Out:
#                      Placed In  Class 10 Percentage  Class 12 Percentage  \
# 0                    Teachnook                   59                   53
# 1                   eInfochips                   86                   73
# 2                     Rockwell                   83                   73
# 3  Cognizant (Genc), Capgemini                   93                   84
# 4                          NaN                   82                   73
#
#    Degree Percentage  Degree CGPA  Live Backlogs  Education Gap  \
# 0                 70            8              0              0
# 1                 67            7              0              0
# 2                 77            8              0              0
# 3                 85            9              0              1
# 4                 78            9              0              0
#
#   Year Down in Engineering (in Years)  \
# 0                                   1
# 1                                 NaN
# ...
