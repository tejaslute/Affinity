# %%
import pandas as pd
df = pd.read_csv("Cleaned_data_Col_3,4,5.csv")
df.head()
# Out:
#                      Placed In  Class 10 Percentage  Class 12 Percentage  \
# 0                    Teachnook                   59                   53
# 1                   eInfochips                   86                   73
# 2                     Rockwell                   83                   73
# 3  Cognizant (Genc), Capgemini                   93                   84
# 4                          NaN                   82                   73
#
#    Degree Percentage Degree CGPA Number of Live Backlogs  \
# 0                 70         7.8                      na
# 1                 67        7.47                     NaN
# 2                 77        8.49                       0
# 3                 85        9.04                       0
# 4                 78         NaN                      na
#
#   Educational GAP (in Years) Year Down in Engineering (in Years)  \
# 0                        NaN                                   1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 861 entries, 0 to 860
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Placed In                            664 non-null    object
#  1   Class 10 Percentage                  861 non-null    int64
#  2   Class 12 Percentage                  861 non-null    int64
#  3   Degree Percentage                    861 non-null    int64
#  4   Degree CGPA                          793 non-null    object
#  5   Number of Live Backlogs              848 non-null    object
#  6   Educational GAP (in Years)           626 non-null    object
#  7   Year Down in Engineering (in Years)  644 non-null    object
#  8   Internship Details                   292 non-null    object
#  9   BE Project Details                   165 non-null    object
# dtypes: int64(3), object(7)
# memory usage: 67.4+ KB

# %%
df['Degree CGPA'].unique()
# Out:
# array(['7.8', '7.47', '8.49', '9.04', nan, '9.19', '8.496', '8.68',
#        '8.29', '7.86', '7.66', '7.99', '7.56', '6.8', '8.37', '8.28',
#        '9.046', '7.61', '8.58', '6.91', '8.96', '8.6', '8.46', '8.52',
#        '8', '7.7', '8.39', '6.89', '8.89', '8.091', '7.48', '8.09',
#        '8.18', '7.73', '7.34', '8.44', '8.4', '7.05', '7.97', '8.19',
#        '6.6', '8.38', '8.23', '8.31', '7.98', '7.26', '7.65', '8.5',
#        '8.14', '7.95', '6.9', '7.3', '8.47', '8.73', '8.48', '9.14',
#        '8.03', '6.26', '7.93', '7.11', '7.58', '8.22', '8.32', '8.45',
#        '8.82', '7.876', '8.8', '9.07', '9.17', '-', '7.9', '9.11', '8.56',
#        '9.335', '9.82', '30', '8.27', '8.1', '8.67', '9.74', '8.92',
#        '8.16', '8.9', '9.75', '9.55', '8.2', '9.075', '9.57', '9.53',
#        '9.268', '9.1', '9.4', '7.83', '9.67', '9.16', '8.63', '8.25',
#        '9.58', '8.64', 'NIL', '9.05', '8.99', '7.87', '8.26', '8.65',
# ...

# %%
backup = df
backup.head()
# Out:
#                      Placed In  Class 10 Percentage  Class 12 Percentage  \
# 0                    Teachnook                   59                   53
# 1                   eInfochips                   86                   73
# 2                     Rockwell                   83                   73
# 3  Cognizant (Genc), Capgemini                   93                   84
# 4                          NaN                   82                   73
#
#    Degree Percentage Degree CGPA Number of Live Backlogs  \
# 0                 70         7.8                      na
# 1                 67        7.47                     NaN
# 2                 77        8.49                       0
# 3                 85        9.04                       0
# 4                 78         NaN                      na
#
#   Educational GAP (in Years) Year Down in Engineering (in Years)  \
# 0                        NaN                                   1
# ...

# %%
df.isnull().sum()
# Out:
# Placed In                              197
# Class 10 Percentage                      0
# Class 12 Percentage                      0
# Degree Percentage                        0
# Degree CGPA                             68
# Number of Live Backlogs                 13
# Educational GAP (in Years)             235
# Year Down in Engineering (in Years)    217
# Internship Details                     569
# BE Project Details                     696
# dtype: int64

# %%
def remove():
    df['Degree CGPA'].replace(['nan', '-','NIL', '.' , '0','NL','---',"I don't have updated S.E results", "No"
                                    , 'na', 'Na'], None, inplace=True)
    df['Degree CGPA'].replace('7.93(approx)', "7.9", inplace=True)
    df['Degree CGPA'].replace('9.765 CGPA', "9.7", inplace=True)
remove()

# %%
df['Degree CGPA'].unique()
# Out:
# array(['7.8', '7.47', '8.49', '9.04', nan, '9.19', '8.496', '8.68',
#        '8.29', '7.86', '7.66', '7.99', '7.56', '6.8', '8.37', '8.28',
#        '9.046', '7.61', '8.58', '6.91', '8.96', '8.6', '8.46', '8.52',
#        '8', '7.7', '8.39', '6.89', '8.89', '8.091', '7.48', '8.09',
#        '8.18', '7.73', '7.34', '8.44', '8.4', '7.05', '7.97', '8.19',
#        '6.6', '8.38', '8.23', '8.31', '7.98', '7.26', '7.65', '8.5',
#        '8.14', '7.95', '6.9', '7.3', '8.47', '8.73', '8.48', '9.14',
#        '8.03', '6.26', '7.93', '7.11', '7.58', '8.22', '8.32', '8.45',
#        '8.82', '7.876', '8.8', '9.07', '9.17', None, '7.9', '9.11',
#        '8.56', '9.335', '9.82', '30', '8.27', '8.1', '8.67', '9.74',
#        '8.92', '8.16', '8.9', '9.75', '9.55', '8.2', '9.075', '9.57',
#        '9.53', '9.268', '9.1', '9.4', '7.83', '9.67', '9.16', '8.63',
#        '8.25', '9.58', '8.64', '9.05', '8.99', '7.87', '8.26', '8.65',
# ...

# %%
df.isnull().sum()
# Out:
# Placed In                              197
# Class 10 Percentage                      0
# Class 12 Percentage                      0
# Degree Percentage                        0
# Degree CGPA                             88
# Number of Live Backlogs                 13
# Educational GAP (in Years)             235
# Year Down in Engineering (in Years)    217
# Internship Details                     569
# BE Project Details                     696
# dtype: int64

# %%
df['Degree CGPA'].replace(nan, None, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 df['Degree CGPA'].replace(nan, None, inplace=True)
#
# NameError: name 'nan' is not defined

# %%
df.isnull().sum()
# Out:
# Placed In                              197
# Class 10 Percentage                      0
# Class 12 Percentage                      0
# Degree Percentage                        0
# Degree CGPA                             88
# Number of Live Backlogs                 13
# Educational GAP (in Years)             235
# Year Down in Engineering (in Years)    217
# Internship Details                     569
# BE Project Details                     696
# dtype: int64

# %%
df['Degree CGPA'] = df['Degree CGPA'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 861 entries, 0 to 860
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Placed In                            664 non-null    object
#  1   Class 10 Percentage                  861 non-null    int64
#  2   Class 12 Percentage                  861 non-null    int64
#  3   Degree Percentage                    861 non-null    int64
#  4   Degree CGPA                          773 non-null    float64
#  5   Number of Live Backlogs              848 non-null    object
#  6   Educational GAP (in Years)           626 non-null    object
#  7   Year Down in Engineering (in Years)  644 non-null    object
#  8   Internship Details                   292 non-null    object
#  9   BE Project Details                   165 non-null    object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 67.4+ KB

# %%
df.describe()
# Out:
#        Class 10 Percentage  Class 12 Percentage  Degree Percentage  \
# count           861.000000           861.000000         861.000000
# mean             85.498258            73.540070          78.429733
# std               7.576681            21.278274           7.905473
# min              57.000000            50.000000          43.000000
# 25%              82.000000            68.000000          74.000000
# 50%              87.000000            73.000000          78.000000
# 75%              92.000000            78.000000          84.000000
# max              98.000000           650.000000          99.000000
#
#        Degree CGPA
# count   773.000000
# mean      8.856724
# std       3.648633
# min       5.314750
# 25%       8.210000
# 50%       8.760000
# 75%       9.250000
# max      96.280000

# %%
df = df[df['Degree CGPA'] < 10]

# %%
df.describe()
# Out:
#        Class 10 Percentage  Class 12 Percentage  Degree Percentage  \
# count           769.000000           769.000000         769.000000
# mean             85.881664            73.832250          78.703511
# std               7.333946            22.314786           8.076329
# min              57.000000            50.000000          43.000000
# 25%              82.000000            69.000000          74.000000
# 50%              87.000000            73.000000          79.000000
# 75%              92.000000            78.000000          84.000000
# max              98.000000           650.000000          99.000000
#
#        Degree CGPA
# count   769.000000
# mean      8.644097
# std       0.770672
# min       5.314750
# 25%       8.210000
# 50%       8.750000
# 75%       9.240000
# max       9.940000

# %%
df = df[df['Class 12 Percentage'] < 100]

# %%
df.describe()
# Out:
#        Class 10 Percentage  Class 12 Percentage  Degree Percentage  \
# count           768.000000           768.000000         768.000000
# mean             85.871094            73.082031          78.700521
# std               7.332861             8.075897           8.081166
# min              57.000000            50.000000          43.000000
# 25%              82.000000            68.750000          74.000000
# 50%              87.000000            73.000000          79.000000
# 75%              92.000000            78.000000          84.250000
# max              98.000000            95.000000          99.000000
#
#        Degree CGPA
# count   768.000000
# mean      8.643854
# std       0.771145
# min       5.314750
# 25%       8.207500
# 50%       8.750000
# 75%       9.240000
# max       9.940000

# %%
df['Degree CGPA'] =df['Degree CGPA'].round(0)
df.head()
# Out:
#                         Placed In  Class 10 Percentage  Class 12 Percentage  \
# 0                       Teachnook                   59                   53
# 1                      eInfochips                   86                   73
# 2                        Rockwell                   83                   73
# 3     Cognizant (Genc), Capgemini                   93                   84
# 5  Cognizant (Genc), Worley Group                   87                   83
#
#    Degree Percentage  Degree CGPA Number of Live Backlogs  \
# 0                 70          8.0                      na
# 1                 67          7.0                     NaN
# 2                 77          8.0                       0
# 3                 85          9.0                       0
# 5                 85          9.0                       0
#
#   Educational GAP (in Years) Year Down in Engineering (in Years)  \
# 0                        NaN                                   1
# ...

# %%
df['Degree CGPA'] =df['Degree CGPA'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 768 entries, 0 to 859
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Placed In                            619 non-null    object
#  1   Class 10 Percentage                  768 non-null    int64
#  2   Class 12 Percentage                  768 non-null    int64
#  3   Degree Percentage                    768 non-null    int64
#  4   Degree CGPA                          768 non-null    int32
#  5   Number of Live Backlogs              761 non-null    object
#  6   Educational GAP (in Years)           573 non-null    object
#  7   Year Down in Engineering (in Years)  587 non-null    object
#  8   Internship Details                   269 non-null    object
#  9   BE Project Details                   152 non-null    object
# dtypes: int32(1), int64(3), object(6)
# memory usage: 63.0+ KB

# %%
df.head()
# Out:
#                         Placed In  Class 10 Percentage  Class 12 Percentage  \
# 0                       Teachnook                   59                   53
# 1                      eInfochips                   86                   73
# 2                        Rockwell                   83                   73
# 3     Cognizant (Genc), Capgemini                   93                   84
# 5  Cognizant (Genc), Worley Group                   87                   83
#
#    Degree Percentage  Degree CGPA Number of Live Backlogs  \
# 0                 70            8                      na
# 1                 67            7                     NaN
# 2                 77            8                       0
# 3                 85            9                       0
# 5                 85            9                       0
#
#   Educational GAP (in Years) Year Down in Engineering (in Years)  \
# 0                        NaN                                   1
# ...

# %%
df['Degree CGPA'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 768 entries, 0 to 859
# Series name: Degree CGPA
# Non-Null Count  Dtype
# --------------  -----
# 768 non-null    int32
# dtypes: int32(1)
# memory usage: 9.0 KB

# %%
df.isnull().sum()
# Out:
# Placed In                              149
# Class 10 Percentage                      0
# Class 12 Percentage                      0
# Degree Percentage                        0
# Degree CGPA                              0
# Number of Live Backlogs                  7
# Educational GAP (in Years)             195
# Year Down in Engineering (in Years)    181
# Internship Details                     499
# BE Project Details                     616
# dtype: int64

# %%
df['Degree CGPA'].unique()
# Out:
# array([ 8,  7,  9,  6, 10,  5])

# %%
df1 = backup
df1.head()
# Out:
#                      Placed In  Class 10 Percentage  Class 12 Percentage  \
# 0                    Teachnook                   59                   53
# 1                   eInfochips                   86                   73
# 2                     Rockwell                   83                   73
# 3  Cognizant (Genc), Capgemini                   93                   84
# 4                          NaN                   82                   73
#
#    Degree Percentage  Degree CGPA Number of Live Backlogs  \
# 0                 70         7.80                      na
# 1                 67         7.47                     NaN
# 2                 77         8.49                       0
# 3                 85         9.04                       0
# 4                 78          NaN                      na
#
#   Educational GAP (in Years) Year Down in Engineering (in Years)  \
# 0                        NaN                                   1
# ...

# %% [markdown]
# # New Started

# %%
def remove():
    df1['Degree CGPA'].replace(['nan', '-','NIL', '.' , '0','NL','---',"I don't have updated S.E results", "No"
                                    , 'na', 'Na'], None, inplace=True)
    df1['Degree CGPA'].replace('7.93(approx)', "7.9", inplace=True)
    df1['Degree CGPA'].replace('9.765 CGPA', "9.7", inplace=True)
remove()

# %%
df1.isnull().sum()
# Out:
# Placed In                              197
# Class 10 Percentage                      0
# Class 12 Percentage                      0
# Degree Percentage                        0
# Degree CGPA                             88
# Number of Live Backlogs                 13
# Educational GAP (in Years)             235
# Year Down in Engineering (in Years)    217
# Internship Details                     569
# BE Project Details                     696
# dtype: int64

# %%
df1['Degree CGPA'] = df1['Degree CGPA'].astype(float)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 861 entries, 0 to 860
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Placed In                            664 non-null    object
#  1   Class 10 Percentage                  861 non-null    int64
#  2   Class 12 Percentage                  861 non-null    int64
#  3   Degree Percentage                    861 non-null    int64
#  4   Degree CGPA                          773 non-null    float64
#  5   Number of Live Backlogs              848 non-null    object
#  6   Educational GAP (in Years)           626 non-null    object
#  7   Year Down in Engineering (in Years)  644 non-null    object
#  8   Internship Details                   292 non-null    object
#  9   BE Project Details                   165 non-null    object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 67.4+ KB

# %%
df1['Degree CGPA'] = df1['Degree CGPA'].fillna(df1['Degree CGPA'].mean())
df1.isnull().sum()
# Out:
# Placed In                              197
# Class 10 Percentage                      0
# Class 12 Percentage                      0
# Degree Percentage                        0
# Degree CGPA                              0
# Number of Live Backlogs                 13
# Educational GAP (in Years)             235
# Year Down in Engineering (in Years)    217
# Internship Details                     569
# BE Project Details                     696
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 861 entries, 0 to 860
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Placed In                            664 non-null    object
#  1   Class 10 Percentage                  861 non-null    int64
#  2   Class 12 Percentage                  861 non-null    int64
#  3   Degree Percentage                    861 non-null    int64
#  4   Degree CGPA                          861 non-null    float64
#  5   Number of Live Backlogs              848 non-null    object
#  6   Educational GAP (in Years)           626 non-null    object
#  7   Year Down in Engineering (in Years)  644 non-null    object
#  8   Internship Details                   292 non-null    object
#  9   BE Project Details                   165 non-null    object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 67.4+ KB

# %%
df1.describe()
# Out:
#        Class 10 Percentage  Class 12 Percentage  Degree Percentage  \
# count           861.000000           861.000000         861.000000
# mean             85.498258            73.540070          78.429733
# std               7.576681            21.278274           7.905473
# min              57.000000            50.000000          43.000000
# 25%              82.000000            68.000000          74.000000
# 50%              87.000000            73.000000          78.000000
# 75%              92.000000            78.000000          84.000000
# max              98.000000           650.000000          99.000000
#
#        Degree CGPA
# count   861.000000
# mean      8.856724
# std       3.456922
# min       5.314750
# 25%       8.280000
# 50%       8.856724
# 75%       9.190000
# max      96.280000

# %%
df1 = df1[df1['Degree CGPA'] < 10]
df1 = df1[df1['Class 12 Percentage'] < 100]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 856 entries, 0 to 860
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Placed In                            659 non-null    object
#  1   Class 10 Percentage                  856 non-null    int64
#  2   Class 12 Percentage                  856 non-null    int64
#  3   Degree Percentage                    856 non-null    int64
#  4   Degree CGPA                          856 non-null    float64
#  5   Number of Live Backlogs              843 non-null    object
#  6   Educational GAP (in Years)           624 non-null    object
#  7   Year Down in Engineering (in Years)  642 non-null    object
#  8   Internship Details                   291 non-null    object
#  9   BE Project Details                   165 non-null    object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 73.6+ KB

# %%
df1['Degree CGPA'] = df1['Degree CGPA'].round(0)
df1.head()
# Out:
#                      Placed In  Class 10 Percentage  Class 12 Percentage  \
# 0                    Teachnook                   59                   53
# 1                   eInfochips                   86                   73
# 2                     Rockwell                   83                   73
# 3  Cognizant (Genc), Capgemini                   93                   84
# 4                          NaN                   82                   73
#
#    Degree Percentage  Degree CGPA Number of Live Backlogs  \
# 0                 70          8.0                      na
# 1                 67          7.0                     NaN
# 2                 77          8.0                       0
# 3                 85          9.0                       0
# 4                 78          9.0                      na
#
#   Educational GAP (in Years) Year Down in Engineering (in Years)  \
# 0                        NaN                                   1
# ...

# %%
df1['Degree CGPA'] =df1['Degree CGPA'].astype(int)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 856 entries, 0 to 860
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Placed In                            659 non-null    object
#  1   Class 10 Percentage                  856 non-null    int64
#  2   Class 12 Percentage                  856 non-null    int64
#  3   Degree Percentage                    856 non-null    int64
#  4   Degree CGPA                          856 non-null    int32
#  5   Number of Live Backlogs              843 non-null    object
#  6   Educational GAP (in Years)           624 non-null    object
#  7   Year Down in Engineering (in Years)  642 non-null    object
#  8   Internship Details                   291 non-null    object
#  9   BE Project Details                   165 non-null    object
# dtypes: int32(1), int64(3), object(6)
# memory usage: 70.2+ KB

# %%
df1.to_csv(r"C:\Users\Rohit Bhapkar\Desktop\Be Project\Final Model\Cleaned_data_Col_6.csv", index=False)

# %%
d2 = pd.read_csv("Cleaned_data_Col_6.csv")
d2.head()
# Out:
#                      Placed In  Class 10 Percentage  Class 12 Percentage  \
# 0                    Teachnook                   59                   53
# 1                   eInfochips                   86                   73
# 2                     Rockwell                   83                   73
# 3  Cognizant (Genc), Capgemini                   93                   84
# 4                          NaN                   82                   73
#
#    Degree Percentage  Degree CGPA Number of Live Backlogs  \
# 0                 70            8                      na
# 1                 67            7                     NaN
# 2                 77            8                       0
# 3                 85            9                       0
# 4                 78            9                      na
#
#   Educational GAP (in Years) Year Down in Engineering (in Years)  \
# 0                        NaN                                   1
# ...
