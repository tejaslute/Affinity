# %%
import pandas as pd
df = pd.read_csv("Cleaned_Data_Col_8.csv")
df.head()
# Out:
#                      Placed In  Class 10 Percentage  Class 12 Percentage  \
# 0                    Teachnook                   59                   53
# 1                   eInfochips                   86                   73
# 2                     Rockwell                   83                   73
# 3  Cognizant (Genc), Capgemini                   93                   84
# 4                          NaN                   82                   73
#
#    Degree Percentage  Degree CGPA  Live Backlogs  Education Gap  \
# 0                 70            8              0              0
# 1                 67            7              0              0
# 2                 77            8              0              0
# 3                 85            9              0              1
# 4                 78            9              0              0
#
#   Year Down in Engineering (in Years)  \
# 0                                   1
# 1                                 NaN
# ...

# %%
df.rename(columns={"Year Down in Engineering (in Years)": "Year down"},inplace=True)
df.head()
# Out:
#                      Placed In  Class 10 Percentage  Class 12 Percentage  \
# 0                    Teachnook                   59                   53
# 1                   eInfochips                   86                   73
# 2                     Rockwell                   83                   73
# 3  Cognizant (Genc), Capgemini                   93                   84
# 4                          NaN                   82                   73
#
#    Degree Percentage  Degree CGPA  Live Backlogs  Education Gap Year down  \
# 0                 70            8              0              0         1
# 1                 67            7              0              0       NaN
# 2                 77            8              0              0       NaN
# 3                 85            9              0              1       NaN
# 4                 78            9              0              0       NaN
#
#                                   Internship Details BE Project Details
# ...

# %%
df['Year down'].unique()
# Out:
# array(['1', nan, '2', '1 year', '0', '4', 'None', 'No', '3', '00', 'Zero',
#        'Three', '0 years', '-', 'NO', '0 Years', 'none', '2019-20', 'no',
#        '0.5 yrs', '0.0', '1 YEAR', 'One year', ',0', '2019', '2018',
#        '2018-2019', 'NIL', '--', 'NONE', '2017-19', '2017 to 2018',
#        '2015-17-18-19', 'MHT-CET', 'FE', '1Y'], dtype=object)

# %%
def remove():
    df['Year down'].replace(['None', 'No', '00', 'Zero','0 years', '-', 'NO', '0 Years', 'none',
                             'no', '0.5 yrs', '0.0', ',0', 'NIL', '--', 'NONE','MHT-CET', 'FE' ], "0", inplace=True)
    df['Year down'].replace(['1 year', '2019-20','1 YEAR', 'One year', '2019', '2018',
                             '2018-2019', '2017 to 2018', '1Y'], "1", inplace=True)
    df['Year down'].replace(['Three'], "3", inplace=True)
    df['Year down'].replace(['2015-17-18-19'], "4", inplace=True)
    df['Year down'].replace(['2017-19'],"2", inplace= True)
         
remove()

# %%
df.isnull().sum()
# Out:
# Placed In              197
# Class 10 Percentage      0
# Class 12 Percentage      0
# Degree Percentage        0
# Degree CGPA              0
# Live Backlogs            0
# Education Gap            0
# Year down              214
# Internship Details     565
# BE Project Details     691
# dtype: int64

# %%
df['Year down'].unique()
# Out:
# array(['1', nan, '2', '0', '4', '3'], dtype=object)

# %%
df['Year down'] = df['Year down'].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 856 entries, 0 to 855
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Placed In            659 non-null    object
#  1   Class 10 Percentage  856 non-null    int64
#  2   Class 12 Percentage  856 non-null    int64
#  3   Degree Percentage    856 non-null    int64
#  4   Degree CGPA          856 non-null    int64
#  5   Live Backlogs        856 non-null    int64
#  6   Education Gap        856 non-null    int64
#  7   Year down            642 non-null    float64
#  8   Internship Details   291 non-null    object
#  9   BE Project Details   165 non-null    object
# dtypes: float64(1), int64(6), object(3)
# memory usage: 67.0+ KB

# %%
df['Year down'] = df['Year down'].fillna("0")
df.isnull().sum()
# Out:
# Placed In              197
# Class 10 Percentage      0
# Class 12 Percentage      0
# Degree Percentage        0
# Degree CGPA              0
# Live Backlogs            0
# Education Gap            0
# Year down                0
# Internship Details     565
# BE Project Details     691
# dtype: int64

# %%
df['Year down'] = df['Year down'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 856 entries, 0 to 855
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Placed In            659 non-null    object
#  1   Class 10 Percentage  856 non-null    int64
#  2   Class 12 Percentage  856 non-null    int64
#  3   Degree Percentage    856 non-null    int64
#  4   Degree CGPA          856 non-null    int64
#  5   Live Backlogs        856 non-null    int64
#  6   Education Gap        856 non-null    int64
#  7   Year down            856 non-null    int32
#  8   Internship Details   291 non-null    object
#  9   BE Project Details   165 non-null    object
# dtypes: int32(1), int64(6), object(3)
# memory usage: 63.7+ KB

# %%
df['Year down'].unique()
# Out:
# array([1, 0, 2, 4, 3])

# %%
df.to_csv(r"C:\Users\Rohit Bhapkar\Desktop\Be Project\Final Model\Cleaned_data_Col_9.csv", index=False)

# %%
df.head()
# Out:
#                      Placed In  Class 10 Percentage  Class 12 Percentage  \
# 0                    Teachnook                   59                   53
# 1                   eInfochips                   86                   73
# 2                     Rockwell                   83                   73
# 3  Cognizant (Genc), Capgemini                   93                   84
# 4                          NaN                   82                   73
#
#    Degree Percentage  Degree CGPA  Live Backlogs  Education Gap  Year down  \
# 0                 70            8              0              0          1
# 1                 67            7              0              0          0
# 2                 77            8              0              0          0
# 3                 85            9              0              1          0
# 4                 78            9              0              0          0
#
#                                   Internship Details BE Project Details
# ...

# %%
df1 = df
df1.head()
# Out:
#                      Placed In  Class 10 Percentage  Class 12 Percentage  \
# 0                    Teachnook                   59                   53
# 1                   eInfochips                   86                   73
# 2                     Rockwell                   83                   73
# 3  Cognizant (Genc), Capgemini                   93                   84
# 4                          NaN                   82                   73
#
#    Degree Percentage  Degree CGPA  Live Backlogs  Education Gap  Year down  \
# 0                 70            8              0              0          1
# 1                 67            7              0              0          0
# 2                 77            8              0              0          0
# 3                 85            9              0              1          0
# 4                 78            9              0              0          0
#
#                                   Internship Details BE Project Details
# ...

# %%
df['Internship Details'].unique()
# Out:
# array([nan,
#        '1 month internship as an biomedical engineer in hospital after diploma completion',
#        'Industrial training at MIMIC Info Tech',
#        'Industrial training of 10 days was done in which we were taught basic introduction to LabVIEW , how to design the front panel, how to give and get inputs. Also we were taught basic Machine Vision System, we had a hands on experience to detect the flaws and automate it.   Also 1 month project based internship was done at FSM Smart Manufacturing. This was organised by IITD-AIA under "FSM Summer Internship programme 2021". Here i have worke on Codesys software and have written ladder logic to control severa machines and a lab, also have made different HMI screens.',
#        'Industrial training of LABview & machine vision software',
#        'One month training in MIT college latur(diploma)',
#        'FSM Summer internship by IITD-AIA foundation for Smart Manufacturing Level -1 Completed',
#        'Digital Marketing',
# ...

# %%
df['BE Project Details'].unique()
# Out:
# array([nan, 'N.A', 'Self Diriving Car using Computer Vision', 'None',
#        'no', '-',
# ...

# %%
def remove():
    df['Internship Details'].replace(['1 month internship as an biomedical engineer in hospital after diploma completion',
       'Industrial training at MIMIC Info Tech',
       'Industrial training of 10 days was done in which we were taught basic introduction to LabVIEW , how to design the front panel, how to give and get inputs. Also we were taught basic Machine Vision System, we had a hands on experience to detect the flaws and automate it.   Also 1 month project based internship was done at FSM Smart Manufacturing. This was organised by IITD-AIA under "FSM Summer Internship programme 2021". Here i have worke on Codesys software and have written ladder logic to control severa machines and a lab, also have made different HMI screens.',
       'Industrial training of LABview & machine vision software',
       'One month training in MIT college latur(diploma)',
       'FSM Summer internship by IITD-AIA foundation for Smart Manufacturing Level -1 Completed',
       'Digital Marketing',
       'Trainee Instrumentation Engineer at Sugar Factory for one year.', 'Industrial Training Batches are starting from 1st of February 2021 to 10th of February 2021.', 'one month training at 2 wheeler workshop',
       'Industrial Training on Labview and Vision system,',
       'Jr. Biomedical Engineer D Y Patil College  Hospital  and Reserch Center Pimpri Pune',
       'Industrial training of LabVIEW and Machine Vision Software',
       'Industrial training of LabVIEW software',
       'Industrial training of LabVIEW',
       'Industrial Training of Labview Software and Machine Vision System.',
       'internship at ABC automations',
       'After second year of diploma l done the  intership 1 months on 2018', '1month training in Alpha Super Specility Hospital (during diploma)',
       'worked with Radio Frequency identification tags installer to install tags in shops for 3 months',
       'SSM summer internship by IIT DAIA foundation for smart manufacturing level one completeProject Details \n1)Automatic Railway Gate Controller\n       The working of the project is very simple.Practically, the two IR sensors are placed at left and right side of the railway gate. The distance between the two IR sensors is dependent on the length of the train. In general we have to consider the longest train in that route.If the sensor 1 detects the arrival of the train, microcontroller starts the motor with the help of motor driver in order to close the gate.The gate remains closed as the train passes the crossing.\nWhen the train crosses the gate and reaches second sensor, it detects the train and the microcontroller will open the gate.\n\n2)Solar Tracking Using Solar Inverter\n\n3)Voice Control Robot',
       'Industrial Training of Labview software and machine vision software',
       'Work experience in Electrical field',
       'Camtech Manufacturing Industrial Experience,  IOT Internship, Robotic Internship.',
       'Industrial Training of Labview and Machine Vision software',
       'Industrial Training and view of control lab and unit plant',
       'Introduction to C programing language , Decision control structures,arrays and function.',
       '6 months of internship during which we will be expected to provide a total of 440 hrs. For conducting citizen training on Home Equal Planet.',
       'Get set from fresher to industry ready @pimpri chinchwad,pune',
       'Internship about construction detailing, all processes occurs in construction. Also about project management.',
       'Knowhow school Freshers to Industry ready',
       '1 month Internship at construction of House',
       '2 months on site intership at Birla coorporation, chandera unit, chittorgarh, Rajasthan',
       '3 Months onsite internship at Know How Schools',
       'Smart city CC road road,Wakad', 'DESIGNING OF BUILDINGS IN STAAD',
       'Industry ready civil RCC module', 'No', 'Site Work and Desining.',
       'on-site intership with know how school as well as online internship with a government known start under guidstart upof 25+ years experience of project manager', 'construction site',
       'Interned as Campus Ambassador at e-cell IIM Calcutta for Tata social enterprise challenge.',
       'Know How',
       'On field  eg. Road construction & Building construction',
       'Social media marketing',
       "Domain-Specific:    \n1) GuruKrupa Constructions, Ahmednagar — Site Managing Intern.    \n2) Saisamruddhi Developers — Site Managing Intern.    \nOthers:    \n1) SpringJaunter Information Technology & Services, Navi Mumbai — Programming Intern    \n2) Virtual Internship Program (Seller Services), Amazon Pay    \n3) Project Statecraft(Policy Thinktank)— Operations Associate.    \n4) LIDIFU.com, Pune— Human Resource(HR) Manager    \n5) Gradeup— Campus Ambassador    \n\nPOSITIONS OF RESPONSIBILITY    \nChairman—  Civil Engineering Student Association, DYPCOE.    \nFounder President—  DYP Students' Chapter of American Concrete Institute.    \nEvent Production Head— TEDxDYPCOE.    \nAdministrator— ‘Coursera for Campus’ Program.    \nMember, Board of Directors— Entrepreneur Development Cell- PHOENIX, DYPCOE.    \nChairperson— Competitive Examination Cell, DYPCOE.    \nEvent Head & First-Year Coordinator— Technical Fest 2019, DYPCOE.",
       '1 Month internship at family business sites',
       'Internship RCC Module Batch 11 Reg. Form',
       '2 month Internship in 2020.',
       'Construction of residential house at khamgoan', 'I had worked as a volunteer , where i had shoecased the ngo infront of people',
       'On Feild Construction.',
       '1 month internship on site in  construction of company',
       'I have completed my internship from Rainbow constructions. I have studied about drawing reading, slab construction, waterproofing, estimation of concrete.',
       '.', 'Swapnapurti construction on field construction internship',
       '3Month internship at SS Enterprises (PWD work of bridge maintenance)', '1) Taken 3 months of site experience of building construction at solapur 2) Taken 2 months of experience in construction consultancy at Pandharpur 3) Taken 2 month of autocad experience in consultancy at Pandharpur',
       '1)Junior Site Engineer at True Build Engineering, pashan, pune  2) Meera Construction, Pune',
       'Trainee Engineer for 1 Month in June 2018.',
       'Getting training of design engineer and quantity surveyor in reputed architecture firm since June 2021',
       '1. Subject Matter Expert, Chegg Inc. (Nov 2020 - Present) : Solved various questions asked by students from Computer Science. It covers all type of subjects such as Data Structures, Algorithms, Computer Networks, Databases, etc.',
       'Campus ambassador for the internshala',
       '1. Subject Matter Expert, Chegg Inc. (Nov 2020 - Present) : Solved various questions asked by students from Computer Science. It covers all type of subjects such as Data Structures, Algorithms, Computer Networks, Databases, etc.\n \n 2. C/C++ Intern, SpringJaunter Tech. (Sep 2018 - Nov 2018) : Implemented the basics of C and C++ like arrays, functions, structures & classes at production level under th',
       'Interned at ESDS Software Solutions in Nashik for 3 weeks. Placed in R&D and Learned about chatbot design and NLP.',
       'Educator at YouTube\n (June 2020-Present)\n Objective\n : I started this YouTube Channel as my hobby where I started to guideand teach students about Android ,Programming, Tech News and Engineering life.\n \n Technical Head (Computer Department)\n (Aug 2020-Present)\n Objective\n : Give guidance to juniors about Competitive programming,Projects, provide resources, organizes technical events and clear their doubts.\n \n Subject Matter Expert,Chegg Inc(Nov 200- Present)',
       'Remote internships.', 'Employability Skill Development Training',
       'Flight Reservation System',
       'Employability Skills Development , Pre Education Program',
       'PEP(Pre Education Program) - Training', 'Campus Business Manager',
       'Working as R&D Intern in Nuance Communications',
       'Cloud Computing Internship',
       'PEP-Pre Education Program provided by EPAM to educate students with hands on programing knowledge',
       'Internship of web development',
       'WordPress Website Developer (2020 Internship) ,Technical Developer (2021)',
       'Summer Intern at Nuance Communications ,Pune for 2 Months',
       "1. 'Software Intern' where I worked on drone camera. \n 2. Campus Business Manager' at the organization\n 3. 'Campus Ambassador', where in I bought a revenue of Rs. 6500 \n 4. 'Social Media Marketing Intern', I was publicizing about the organization\n 5. 'Software Intern', where I am developing a performance testing tool",
       '1.Internship Trainee\nJuly 2021 – Present\nKonecranes\nRemote\n• Working in department Data to Knowledge for project based on BI and Analytics Operations/Support.\n• Learning about Data Warehouse Source, Architecture, Modelling, ETL tool DataStage.\n• Working on Reporting tool Qlikview.\n2.Data Analyst Intern\nJul 2020 – Aug 2020\nRemote\nFriends Union For Energising Lives\n• Giving complete EDA, making Final Report of different Projects done by FUEL.\n• Communicating with beneficiaries of Projects for Data Collection.',
       'Completed a six-month internship at Data Tech Labs as a Research intern.\nCompleted an internship at Swadeshi Khareed as a Website Product Upload and Website Development Intern.',
       'Full Stack Web Developer Intern',
       'Full Stack React Developer Intern Supersapiens Devlab,',
       'Business Intelligence And Data Analytics',
       'Internship At Algorithum Electronics', 'Campus Ambassdor',
       'UI/UX Designer', 'Basics of C & C++', 'Vb.net ,Advance Excel',
       'Web Development', 'I have done my internship at smartknower',
       'Campus Ambassador',
       'Summer Intern at Nuance Communications (Global R&D Team)\nRole: Automation & scripting in Python language.', 'Python-Django backend web development for a b2b e-commerce website',
       '.I had worked in STERLITE TECHNOLOGIES company which is telecom field. The company manufacture the optical fiber cable and provide them. At that time, the company working on digital India project given by government in which the task had to provide the internet in rural areas. After hiring us they provided us training in which they taught what is telecom field, how was the work done, how to do it and also teach the technical knowledge of Optical Fiber Cable like splicing, cladding, etc. A lot of teams      has  been created by company which has worked in different state and district. After joining the team and worked for company, I learn new skills like teamwork, self-reliance, problem solving skills, maturity  ,practical skills, commercial awareness, self-confidence, networking, negotiation skills, stress management, business etiquette, organization and experience like how to interact or communicate with people, how to take responsibilities and how to manage them and if there is problem created how to solve it and also got knowledge of Optical Fiber Cable and telecom field.',
       'Online Internship of LinkedIn Marketing from Internshala',
       'Internship 1-Data science and business analytics intern at sparks foundation, Internship 2- Cyber security summer intern at gurugram Police, Internship 3- Enterprise Tester at virtually testing foundation',
       '1)Goldman schan 1 day virtual internship, 2) Accenture virtual training program',
       'I was working with BSNL', 'In progress', 'Embedded Systems',
       '4 week training at Jammu Power distribution corp ltd',
       '1) Campus Ambassador\n--- Offered promotional items to introduce students to courses\nand workshops offered by Makerdemy . \n--- Helped with planning and hosting of marketing events .\n--- Increased brand recognition in target audience through\ncreative promotions and marketing campaigns .\n2) Marketing Intern\n--- Implemented strategic plans with targeted social media\ncontent to increase awareness about Springfield Olympiads.',
       '2½ month Internship at SNS technosys where I worked on embedded systems, IOT and motor driver based systems',
       '30 Days Internship on AI Masterclass using Python',
       'Training in core activities like Optical fibre communication, Mobile train audio communication, Quad cable communication, Basic signaling system\nZensar ESD Training',
       'optical fibre communication system,quad cable communication system,prs/uts working system,signal interlocking system,basic signalling system, mobile train radio communication',
       'Zensar ESD training 2021', 'ESD Zensar Training 2021',
       'Embedded systems and graphical user interface',
       'Poetry Writing Intership', 'Zensar ESD training',
       'ESD Zensar Training 2020',
       'Brand Ambassador at Viral Fission for 1 month',
       'Data Science and Business Analytics Intern',
       '1) PCB Designing \n2) Workshop on "Exploring Arduino with hands on Experience ".\n3) Online International Workshop on AI and Data science \n4) VLSI System on chip design : Webinar',
       'Participated in zensar ESD training program 2020',
       'PEP program of EPAM',
       'Unschool Community Influencer (July 2020 - One Month Internship)',
       'Business development Associate',
       'Manual (Through Hole) Soldering, SMD Soldering, Component Testing, Power Factor/Load, Voltage, Current Adjustment Skill, PCB Track Fault Tracing, Hands on Experience On Screen Printing, PCB Etching, Cutting & & Drilling, Whole Assembling of Street Lamp, High Mast, Flood Light, High bay',
       'I worked as Sales and Marketing Intern at Unschool where I offered industry-recognized courses to enthusiastic learners to empower their practical understanding of technology.',
       "Under the 'Pradhan Mantri Kaushal Vikas Yojana (PMKVY)' interned at BSNL, Pune in First Year. Was taught cum trained (Theoretically and Practically ) in domains related to Computer Network and Telecommunication. Touched as well as dived into areas like Cryptography, Routers and Modems, Internet and Wireless Communication. Successfully completed the Written, Viva and Practical examinations conducted by the PMKVY Officers",
       '4 weeks Industrial Training at 150 MVA 132/33KV Grid Station, Miran- Sahib, JKPTCL, Jammu',
       '1 month internship program',
       'Worked at SNS TECHNOSYS (Embedded system and IT based solutions) for 2 months',
       'Campus Ambassador in a not for profit organization.', 'BSNL',
       'Online Internship in Information Technology',
       'Frontend Developer Intern', 'Campus Ambassador at F5 Developer',
       'CAMPUS BUSINESS MANAGER', 'Digital Marketing Intern',
       'Digital Director', 'CAMPUS AMBASSADOR INTERNSHIP', 'Support',
       'web development internship', 'Web Devloper',
       'Full Stack Developer Intern', 'Trainee',
       'started on 30th apr 2021', 'Web Developer',
       'Worked in Analyst.Ai company. I worked on documentation and also written some functions.',
       'Digital Marketing And sales Internship',
       'Digital Marketing Internship',
       'Junior ML Engineer at an Omdena Project',
       'Web developmer intern, campus ambassador, HR,social media marketing intern,content creator, content writer intern',
       'IoT and Computer vision internship', 'Software Developer Intern',
       'Zensar ESD Program',
       '1] Junior Flutter Developer | 2] Android Developer & UI/UX Designer',
       'Software Engineer Intern', 'MEAN Stack Developer',
       'Q & A Expert For Computer Science,November 2020 to February 2021',
       '1. web development intership',
       '1.web development internship \n2.campus ambassador internship',
       '1.Tech Intern 2.Technical Instructor',
       'working with the team on important initiatives for software product development.\nAutomating critical product specific use cases. Solving innovatively any product/process specific challenges.',
       'PYTHON DEVELOPER, Software Developer',
       'Software Engineer Intern – Python Developer (Django Web Framework)\nwherein developing & improving system quality by identifying issues and common patterns & enhancing applications by identifying opportunities for improvement, designing & implementing systems.',
       'Web Designing Internship', 'Worked as a Technical Content Writer',
       '1) Web Development Internship 2)Data Science and Training Internship',
       'Q&A Expert (Computer Science) at Chegg India from November 2020 to March 2021                                                               Website Development Intership at Internship Studio from July 2021 till date',
       'Collaborating with lieutenant colonel Nikhil and mentors from Tech Mahindra for developing digital camouflage patterns using DeepLearning algorithms.',
       'Android Developer',        '1) I Worked on projects like Washing Machines,Leak Testing Machines and Fixtures in the Assembly Department Dated from 8th March 2021 to 8th April 2021.\n2) Design and Analysis Of Shock Absorber Dated From 6th July to 24th Aug 2020 in CADD Centre Pakbara.     3)Fuel Cell Technology at NIT ROURKELA.',
       '1) Masters in Vehicle Dynamics\n2) Electric Vehicles',
       '1. Energy Conservation & Management , Energy Auditor for an Textile Industry , Bhiwandi , Maharashtra \n\n2. Unschool Community Influencer , Market research, Promotion sales & marketing \n\n3. Campus Coordinator with NEO foundation for an National Engineering Olympiad 3.0\n\n4. Volunteering & Internship under PAN India Curriculum Development Project by INTELLIFY an initiative by an IIT Delhi Alumni\n\n5. Marketing Internship as an Social Media Marketing Handler , Market research , Influencer, Brand Management',
       'One month internship at Supreme petrochem ltd.',
       'Hybrid and Electric vehicles (Verzeo), Social media marketing (Unschool), Digital and social media marketing(Mridam digital)',
       '1 August 2020 - 31 August 2020 [1 Month]\nWorked on company projects with the use of AUTOCAD and CATIA',
       'Industrial training at Brembo brakes India',
       'Design Intern at Infinity Graphix Technologies',
       'HERO satpuda automobile, Jalgaon( 1 month)',
       'Hybrid Electric Vehicle Internship',
       'Internship in Production department  at Shri Kedareshwar Sahakari Sakhar Karkhana - Ahmednagar',
       '1) Computational Fluid Dynamics and External Aerodynamics \n2) Compressed air leak detection using an Ultrasonic leak detector',
       'INTERNSHIP IN PAYCHEM RPG-\nRAYCHEM RPG IS A JOINT VENTURE BETWEEN PSYCHO ELECTRONIC AND RPG GROUP.THE MAJOR CUSTOMER OF RAYCHEM RPG ARE PCYCHO ELECTRONIC,GLOBALS.\nTHE INTERNSHIP INVOLVED STORE PROCESS IMPROVEMENT LIKE CREATING STORAGE LOCATION IN THE SYSTEM,SIMPLIFYING FIFO OF GOODS INTERNALLY AND EXTERNALLY.',
       'I have done internship in Mehta Enterprise, which is a sheet metal pressed component manufacturing and welded assembling company. Which developed Component for Tata Motors, FIAT INDIA, Force Motor Company & for FIAT Italy.',
       'I did a 15-Days vocational training where I worked under different engineering sections of the company. During my training, I worked on some projects such as setting up a new cold room for storing milk products, maintenance of processing plant (conveyor maintenance) and overhauling of the compressor.',
       'SOCIAL MEDIA MARKETING, MARKETING HEAD', 'Junior Design Engineer',
       'CNC operating and programming',
       'I have finished my 2 months internship at "GreenDriveIndia". Our project was on Retrofitting of Petrol Vehicle into Electric Vehicle. The duration was of 2 months from 10th February,2019 to 11th April,2019',
       'IMPLANT TRAINING', 'WORKS AT MINERAL WATER COMPANY',
       '1.Web developer Intern.\n2.One-week online Internship program on product design-design thinking/innovation/Autodesk fusion 360 organized by N K Orchid College of Engineering & Technology, Solapur.',
       'Verzeo Robotics',
       '1. I have worked on two projects which are camera inspection machine and belt conveyer. I have worked on 2D and 3D design of projects on softwares AutoCAD and CATIA respectively and assembled all the parts to manufacture well equipped machines at Vaishali Automation and Robotics Technologies, Tathawade, Pune.      2. Campus Ambassador at Techfest, IIT, Bombay     3. Executive assistant at Dight International Chambers',
       'Domain:-Hybrid and Electric Vehicles',
       'Department- Production,\nDesignation- Trainee,\nService Period- 01/10/2020 - 30/10/2020',
       'WORKER AS DESIGN ENGINEER AND CAD EXPERT.',
       'Worked in a bike modification centre for about 2 months on modifying a ktm 390.',
       'Planned after permission from  companies.', '_',
       'Site supervisor+cotton bales quality testing+ cotton seed quality testing+raw cotton purcase+production managing',
       'Worked as a junior engineer(trainee) for 20 days in METS in VIZAG and learnt some basics in refitting of coast guard ships..',
       'Worked as Intern at TATA MOTORS.',
       'I worked on Leak Testing Machine, Cylinder Washing Machine and Fixtures in Assembly department.',
       'Duration : 5 May 2018 to 30 May 2018\n1. Gain the extensive knowledge of Sheet Metal Die, Deep Drawing Operations.\n2.Observing the maintenance process of different machines \n3. Assisting in maintenance of deep drawing machine.\n4. Collect the practical knowledge about different manufacturing and industrial process',
       'Industrial Trainee', '2 Month internship at Konecranes.',
       'Machine Learning and Data Analysis',
       'Worked With “Green Drive India” Start-up For 4 Months as Design Intern, On Project Of Electric Bicycle For Delivery Business.',
       'Manufacturing various component in the Workshop',
       'Internship in MACKS SURFACE TREATMENT PVT LTD The first electroplating company in India to be ISO/TS 16949 certified.It is vendor of Gabriel India Ltd, KYB Motorcycle, TVS Motors, BAJAJ, Yamaha, Hyundai , Ford etc. The internship involved the understanding of working principle of Centreless Grinders , CNC (reducing the dimensions of the tube to required value, chamfering ,boring ,threading, gauges) .It also involved the understanding of process of nickle plating and hard chrome plating.',
       'Machine Working',
       'Internship in MACKS SURFACE TREATMENT PVT LTD\nThe first electroplating company in India to be ISO/TS 16949 certified. It is vendor of Gabriel India Ltd, KYB Motorcycle, TVS Motors, BAJAJ, Yamaha, Hyundai , Ford etc. The internship involved the understanding of working principle of Centerless Grinders, CNC (reducing the dimensions of the tube to required value, chamfering, boring, threading, gauges). It also involved the understanding of process of nickel plating and hard chrome plating.',
       'Formula student Team of Dy Patil college of engineering.',
       'HYBRID ELECTRIC VEHICLES', 'Data Science',
       'In year 2017-2018 at ArtFab [Manufacturers of High Precision Components, Hydraulic & Pneumatic Fittings & Fabricated Assemblies',
       'Oerlicon ,shinoli,dist kop',
       'I have done internship at Nashik MIDC for 15 days. During this internship I learned corporate etiquettes, experience of machine handling, plan layout,etc\nDated from 29.05.2018 to 10.06.2018',
       '3 week training program in industry',
       'Metlograpy, checking heat treatment',
       '1) Orange City Alloy Pvt. Ltd. (duration :-15days)\n  2) Modern Engineering (duration :- 3months)',
       'Implementation of 5s',
       'Worked in Street Light Pole Manufacturing Company',
       'I worked in a polymers company',
       "I've completed my internship of 4 month in S.K. Engineering Works.",
       'Inernship at sugar factory', '6 Month Internship',
       'Work as a trainee engineer for five months period.',
       'My industrial training place was assigned as V R Sales. I was worked under the Quality Assurance and Research and Development Division for six months period starting from October 2020 to March 2021.\n  \n  The Quality Assurance and Research and Development Division mainly handles the production product control, Finish product control, Screen preparation, new tile developments etc.',
       'Work as trainee engineer for 6 month,work on sap software',
       'Python Course', 'Diploma engineer trainee',
       'Programming and data science by IIT Madras',
       'Workking In company which is manufacturing anti - vibrational products of higher loads',
       'Quality Control Department', 'Online courses',
       'Department of manufacturing excellence -\n1.Low cost automation\n2.SINTO moulding line improvement\n3.Oiling station',
       'Quality department',
       'Plant trainee (2nd Oct 2020 to 30th Dec 2020)',
       'TECHNICAL INTERN DURING 01.06.2020 - 31.08.2020',
       'I jave done certification in google digital marketing',
       'Software testing Calif code Pvt.ltd',
       'I completed my internship in corrugation box manufacturing company.',
       'Quality Intern At Bedmutha Industries Ltd,Dhule, Maharashtra.']
, "1", inplace=True)
remove()

# %%
df['Internship Details'].unique()
# Out:
# array([nan, '1', 'Not Applied', 'None', 'no', '-',
#        "I am studying in 3rd year so, didn't joined any internship till now.",
#        'Nil', 'No any idea', 'N.A.', 'NIL', '-----'], dtype=object)

# %%
df['Internship Details'].replace(['no', '-', 'Not Applied',"I am studying in 3rd year so, didn't joined any internship till now.",
                                  'Nil', 'No any idea', 'N.A.', 'NIL', '-----',  ], "0", inplace=True)

# %%
df['Internship Details'].unique()
# Out:
# array([nan, '1', '0', 'None'], dtype=object)

# %%
df['Internship Details'].value_counts()
# Out:
# 1       258
# 0        32
# None      1
# Name: Internship Details, dtype: int64

# %%
df.isnull().sum()
# Out:
# Placed In              197
# Class 10 Percentage      0
# Class 12 Percentage      0
# Degree Percentage        0
# Degree CGPA              0
# Live Backlogs            0
# Education Gap            0
# Year down                0
# Internship Details     565
# BE Project Details     691
# dtype: int64

# %%
df['Internship Details'] = df['Internship Details'].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 856 entries, 0 to 855
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Placed In            659 non-null    object
#  1   Class 10 Percentage  856 non-null    int64
#  2   Class 12 Percentage  856 non-null    int64
#  3   Degree Percentage    856 non-null    int64
#  4   Degree CGPA          856 non-null    int64
#  5   Live Backlogs        856 non-null    int64
#  6   Education Gap        856 non-null    int64
#  7   Year down            856 non-null    int32
#  8   Internship Details   291 non-null    float64
#  9   BE Project Details   165 non-null    object
# dtypes: float64(1), int32(1), int64(6), object(2)
# memory usage: 63.7+ KB

# %%
df['Internship Details'].replace('None', "0", inplace=True)

# %%
df['Internship Details'] = df['Internship Details'].fillna(1)
df1.isnull().sum()
# Out:
# Placed In              197
# Class 10 Percentage      0
# Class 12 Percentage      0
# Degree Percentage        0
# Degree CGPA              0
# Live Backlogs            0
# Education Gap            0
# Year down                0
# Internship Details       0
# BE Project Details     691
# dtype: int64

# %%
df['Internship Details'].value_counts()
# Out:
# 1.0    823
# 0.0     33
# Name: Internship Details, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 856 entries, 0 to 855
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Placed In            659 non-null    object
#  1   Class 10 Percentage  856 non-null    int64
#  2   Class 12 Percentage  856 non-null    int64
#  3   Degree Percentage    856 non-null    int64
#  4   Degree CGPA          856 non-null    int64
#  5   Live Backlogs        856 non-null    int64
#  6   Education Gap        856 non-null    int64
#  7   Year down            856 non-null    int32
#  8   Internship Details   856 non-null    float64
#  9   BE Project Details   165 non-null    object
# dtypes: float64(1), int32(1), int64(6), object(2)
# memory usage: 63.7+ KB

# %%
df['Internship Details'] =df['Internship Details'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 856 entries, 0 to 855
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Placed In            659 non-null    object
#  1   Class 10 Percentage  856 non-null    int64
#  2   Class 12 Percentage  856 non-null    int64
#  3   Degree Percentage    856 non-null    int64
#  4   Degree CGPA          856 non-null    int64
#  5   Live Backlogs        856 non-null    int64
#  6   Education Gap        856 non-null    int64
#  7   Year down            856 non-null    int32
#  8   Internship Details   856 non-null    int32
#  9   BE Project Details   165 non-null    object
# dtypes: int32(2), int64(6), object(2)
# memory usage: 60.3+ KB

# %%
df.head()
# Out:
#                      Placed In  Class 10 Percentage  Class 12 Percentage  \
# 0                    Teachnook                   59                   53
# 1                   eInfochips                   86                   73
# 2                     Rockwell                   83                   73
# 3  Cognizant (Genc), Capgemini                   93                   84
# 4                          NaN                   82                   73
#
#    Degree Percentage  Degree CGPA  Live Backlogs  Education Gap  Year down  \
# 0                 70            8              0              0          1
# 1                 67            7              0              0          0
# 2                 77            8              0              0          0
# 3                 85            9              0              1          0
# 4                 78            9              0              0          0
#
#    Internship Details BE Project Details
# ...

# %%
df.to_csv(r"C:\Users\Rohit Bhapkar\Desktop\Be Project\Final Model\Cleaned_data_Col_9.csv", index=False)
